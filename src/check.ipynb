# %%
import polars as pl

# %%
df = pl.read_parquet("../data_manual/bloomberg.parquet")

# %%
4216-4072
# Out:
# 144

# %%
df
# Out:
# shape: (4_216, 388)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ ('TY2     ┆ ('TY2     ┆ ('TY2     ┆ ('TY2     ┆ … ┆ ('91282CN ┆ ('91282CP ┆ ('91282CP ┆ Date     │
# │ Comdty',  ┆ Comdty',  ┆ Comdty',  ┆ Comdty',  ┆   ┆ X Govt',  ┆ Q Govt',  ┆ Y Govt',  ┆ ---      │
# │ 'fut_impl ┆ 'px_volum ┆ 'current_ ┆ 'px_last' ┆   ┆ 'px_last' ┆ 'px_last' ┆ 'px_last' ┆ date     │
# │ ied_re…   ┆ e')       ┆ contra…   ┆ )         ┆   ┆ )         ┆ )         ┆ )         ┆          │
# │ ---       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆          │
# │ f64       ┆ f64       ┆ str       ┆ f64       ┆   ┆ f64       ┆ f64       ┆ f64       ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ -0.14735  ┆ 62.0      ┆ JUN 10    ┆ 114.10937 ┆ … ┆ null      ┆ null      ┆ null      ┆ 2010-01- │
# │           ┆           ┆           ┆ 5         ┆   ┆           ┆           ┆           ┆ 04       │
# │ -0.1563   ┆ 16.0      ┆ JUN 10    ┆ 114.75    ┆ … ┆ null      ┆ null      ┆ null      ┆ 2010-01- │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ 05       │
# │ -0.14667  ┆ 10.0      ┆ JUN 10    ┆ 114.5     ┆ … ┆ null      ┆ null      ┆ null      ┆ 2010-01- │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ 06       │
# │ -0.09428  ┆ 85.0      ┆ JUN 10    ┆ 114.375   ┆ … ┆ null      ┆ null      ┆ null      ┆ 2010-01- │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ 07       │
# │ -0.30483  ┆ 529.0     ┆ JUN 10    ┆ 114.46875 ┆ … ┆ null      ┆ null      ┆ null      ┆ 2010-01- │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ 08       │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …        │
# │ null      ┆ null      ┆ null      ┆ null      ┆ … ┆ null      ┆ null      ┆ null      ┆ 2023-01- │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ 16       │
# │ null      ┆ null      ┆ null      ┆ null      ┆ … ┆ null      ┆ null      ┆ null      ┆ 2023-02- │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ 20       │
# │ null      ┆ null      ┆ null      ┆ null      ┆ … ┆ null      ┆ null      ┆ null      ┆ 2023-05- │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ 29       │
# │ null      ┆ null      ┆ null      ┆ null      ┆ … ┆ null      ┆ null      ┆ null      ┆ 2024-12- │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ 25       │
# │ null      ┆ null      ┆ null      ┆ null      ┆ … ┆ 99.664062 ┆ 99.601562 ┆ null      ┆ 2026-01- │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ 01       │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
# Get the name of the first column
first_col = df.columns[0]
# Find the last non-null value's index in the first column
non_null_indices = df.select(pl.col(first_col).is_not_null()).to_series().to_numpy().nonzero()[0]
if len(non_null_indices) > 0:
    last_non_null_index = non_null_indices[-1]
else:
    last_non_null_index = None
last_non_null_index
# Out:
# np.int64(4072)

# %%
# Select columns whose names contain 'TY2', and keep Date as well
ty2_cols = [col for col in df.columns if 'TU2' in str(col)]
if "Date" not in ty2_cols:
    ty2_cols.append("Date")
df_ty2 = df.select(ty2_cols)
df_out = df_ty2.filter(pl.col("Date") == pl.date(2023, 9, 29))
df_out
# Out:
# shape: (1, 7)
# ┌──────────────┬──────────────┬─────────────┬─────────────┬─────────────┬─────────────┬────────────┐
# │ ('TU2        ┆ ('TU2        ┆ ('TU2       ┆ ('TU2       ┆ ('TU2       ┆ ('TU2       ┆ Date       │
# │ Comdty', 'fu ┆ Comdty', 'cu ┆ Comdty',    ┆ Comdty',    ┆ Comdty',    ┆ Comdty',    ┆ ---        │
# │ t_implied_re ┆ rrent_contra ┆ 'px_last')  ┆ 'fut_ctd_cu ┆ 'fut_cnvs_f ┆ 'px_volume' ┆ date       │
# │ …            ┆ …            ┆ ---         ┆ sip'…       ┆ acto…       ┆ )           ┆            │
# │ ---          ┆ ---          ┆ f64         ┆ ---         ┆ ---         ┆ ---         ┆            │
# │ f64          ┆ str          ┆             ┆ str         ┆ f64         ┆ f64         ┆            │
# ╞══════════════╪══════════════╪═════════════╪═════════════╪═════════════╪═════════════╪════════════╡
# │ 4.02086      ┆ DEC 23       ┆ 101.355469  ┆ 91282CJB    ┆ 0.9835      ┆ 762379.0    ┆ 2023-09-29 │
# └──────────────┴──────────────┴─────────────┴─────────────┴─────────────┴─────────────┴────────────┘

# %%
df_only = df.filter(pl.col("Date") == pl.date(2023, 9, 29)).select(
    [col for col in df.columns if 'fut_implied_repo_rt' in str(col)]
)
df_only
# Out:
# shape: (1, 5)
# ┌───────────────────┬───────────────────┬───────────────────┬───────────────────┬──────────────────┐
# │ ('TY2 Comdty',    ┆ ('FV2 Comdty',    ┆ ('TU2 Comdty',    ┆ ('US2 Comdty',    ┆ ('WN2 Comdty',   │
# │ 'fut_implied_re…  ┆ 'fut_implied_re…  ┆ 'fut_implied_re…  ┆ 'fut_implied_re…  ┆ 'fut_implied_re… │
# │ ---               ┆ ---               ┆ ---               ┆ ---               ┆ ---              │
# │ f64               ┆ f64               ┆ f64               ┆ f64               ┆ f64              │
# ╞═══════════════════╪═══════════════════╪═══════════════════╪═══════════════════╪══════════════════╡
# │ 5.44458           ┆ 4.90742           ┆ 4.02086           ┆ 4.72774           ┆ 4.70734          │
# └───────────────────┴───────────────────┴───────────────────┴───────────────────┴──────────────────┘

# %%
df.null_count()
# Out:
# shape: (1, 388)
# ┌────────────┬────────────┬────────────┬────────────┬───┬───────────┬───────────┬───────────┬──────┐
# │ ('TY2      ┆ ('TY2      ┆ ('TY2      ┆ ('TY2      ┆ … ┆ ('91282CN ┆ ('91282CP ┆ ('91282CP ┆ Date │
# │ Comdty',   ┆ Comdty',   ┆ Comdty',   ┆ Comdty',   ┆   ┆ X Govt',  ┆ Q Govt',  ┆ Y Govt',  ┆ ---  │
# │ 'fut_impli ┆ 'px_volume ┆ 'current_c ┆ 'px_last') ┆   ┆ 'px_last' ┆ 'px_last' ┆ 'px_last' ┆ u32  │
# │ ed_re…     ┆ ')         ┆ ontra…     ┆ ---        ┆   ┆ )         ┆ )         ┆ )         ┆      │
# │ ---        ┆ ---        ┆ ---        ┆ u32        ┆   ┆ ---       ┆ ---       ┆ ---       ┆      │
# │ u32        ┆ u32        ┆ u32        ┆            ┆   ┆ u32       ┆ u32       ┆ u32       ┆      │
# ╞════════════╪════════════╪════════════╪════════════╪═══╪═══════════╪═══════════╪═══════════╪══════╡
# │ 176        ┆ 226        ┆ 146        ┆ 144        ┆ … ┆ 4083      ┆ 4168      ┆ 4194      ┆ 0    │
# └────────────┴────────────┴────────────┴────────────┴───┴───────────┴───────────┴───────────┴──────┘

# %%
df.columns
# Out:
# ["('TY2 Comdty', 'fut_implied_repo_rt')",
#  "('TY2 Comdty', 'px_volume')",
#  "('TY2 Comdty', 'current_contract_month_yr')",
#  "('TY2 Comdty', 'px_last')",
#  "('TY2 Comdty', 'fut_ctd_cusip')",
#  "('TY2 Comdty', 'fut_cnvs_factor')",
#  "('FV2 Comdty', 'fut_implied_repo_rt')",
#  "('FV2 Comdty', 'current_contract_month_yr')",
#  "('FV2 Comdty', 'px_last')",
#  "('FV2 Comdty', 'fut_ctd_cusip')",
#  "('FV2 Comdty', 'fut_cnvs_factor')",
#  "('FV2 Comdty', 'px_volume')",
#  "('TU2 Comdty', 'fut_implied_repo_rt')",
#  "('TU2 Comdty', 'current_contract_month_yr')",
#  "('TU2 Comdty', 'px_last')",
#  "('TU2 Comdty', 'fut_ctd_cusip')",
#  "('TU2 Comdty', 'fut_cnvs_factor')",
#  "('TU2 Comdty', 'px_volume')",
#  "('US2 Comdty', 'fut_implied_repo_rt')",
#  "('US2 Comdty', 'px_volume')",
#  "('US2 Comdty', 'current_contract_month_yr')",
#  "('US2 Comdty', 'px_last')",
#  "('US2 Comdty', 'fut_ctd_cusip')",
#  "('US2 Comdty', 'fut_cnvs_factor')",
#  "('WN2 Comdty', 'fut_implied_repo_rt')",
#  "('WN2 Comdty', 'current_contract_month_yr')",
#  "('WN2 Comdty', 'px_last')",
#  "('WN2 Comdty', 'fut_ctd_cusip')",
#  "('WN2 Comdty', 'fut_cnvs_factor')",
#  "('WN2 Comdty', 'px_volume')",
#  "('USSOB CMPN Curncy', 'px_last')",
#  "('USSOC CMPN Curncy', 'px_last')",
#  "('USSOD CMPN Curncy', 'px_last')",
#  "('USSOE CMPN Curncy', 'px_last')",
#  "('USSOF CMPN Curncy', 'px_last')",
#  "('USSOI CMPN Curncy', 'px_last')",
#  "('912810EV Govt', 'px_last')",
#  "('912810EW Govt', 'px_last')",
#  "('912810EX Govt', 'px_last')",
#  "('912810EY Govt', 'px_last')",
#  "('912810EZ Govt', 'px_last')",
#  "('912810FA Govt', 'px_last')",
#  "('912810FB Govt', 'px_last')",
#  "('912810FE Govt', 'px_last')",
#  "('912810FF Govt', 'px_last')",
#  "('912810FJ Govt', 'px_last')",
#  "('912810FM Govt', 'px_last')",
#  "('912810FT Govt', 'px_last')",
#  "('912810PT Govt', 'px_last')",
#  "('912810PU Govt', 'px_last')",
#  "('912810PW Govt', 'px_last')",
#  "('912810PX Govt', 'px_last')",
#  "('912810QB Govt', 'px_last')",
#  "('912810QC Govt', 'px_last')",
#  "('912810QE Govt', 'px_last')",
#  "('912810QH Govt', 'px_last')",
#  "('912810QL Govt', 'px_last')",
#  "('912810QN Govt', 'px_last')",
#  "('912810QQ Govt', 'px_last')",
#  "('912810QS Govt', 'px_last')",
#  "('912810QT Govt', 'px_last')",
#  "('912810QU Govt', 'px_last')",
#  "('912810RC Govt', 'px_last')",
#  "('912810RD Govt', 'px_last')",
#  "('912810RE Govt', 'px_last')",
#  "('912810RG Govt', 'px_last')",
#  "('912810RH Govt', 'px_last')",
#  "('912810RJ Govt', 'px_last')",
#  "('912810RM Govt', 'px_last')",
#  "('912810RN Govt', 'px_last')",
#  "('912810RP Govt', 'px_last')",
#  "('912810RV Govt', 'px_last')",
#  "('912810RX Govt', 'px_last')",
#  "('912810RY Govt', 'px_last')",
#  "('912810SA Govt', 'px_last')",
#  "('912810SC Govt', 'px_last')",
#  "('912810SE Govt', 'px_last')",
#  "('912810SF Govt', 'px_last')",
#  "('912810SH Govt', 'px_last')",
#  "('912810SJ Govt', 'px_last')",
#  "('912810SK Govt', 'px_last')",
#  "('912810TL Govt', 'px_last')",
#  "('912810TV Govt', 'px_last')",
#  "('912810TW Govt', 'px_last')",
#  "('912810TZ Govt', 'px_last')",
#  "('912810UB Govt', 'px_last')",
#  "('912810UJ Govt', 'px_last')",
#  "('912810UL Govt', 'px_last')",
#  "('9128282A Govt', 'px_last')",
#  "('9128282F Govt', 'px_last')",
#  "('9128282R Govt', 'px_last')",
#  "('9128282S Govt', 'px_last')",
#  "('9128282V Govt', 'px_last')",
#  "('9128283F Govt', 'px_last')",
#  "('9128283L Govt', 'px_last')",
#  "('9128283N Govt', 'px_last')",
#  "('9128283P Govt', 'px_last')",
#  "('9128283V Govt', 'px_last')",
#  "('9128283W Govt', 'px_last')",
#  "('9128283Z Govt', 'px_last')",
#  "('9128284A Govt', 'px_last')",
#  "('9128284B Govt', 'px_last')",
#  "('9128284D Govt', 'px_last')",
#  "('9128284F Govt', 'px_last')",
#  "('9128284M Govt', 'px_last')",
#  "('9128284N Govt', 'px_last')",
#  "('9128284R Govt', 'px_last')",
#  "('9128284S Govt', 'px_last')",
#  "('9128284T Govt', 'px_last')",
#  "('9128284U Govt', 'px_last')",
#  "('9128284V Govt', 'px_last')",
#  "('9128284X Govt', 'px_last')",
#  "('9128284Z Govt', 'px_last')",
#  "('9128285A Govt', 'px_last')",
#  "('9128285B Govt', 'px_last')",
#  "('9128285C Govt', 'px_last')",
#  "('9128285D Govt', 'px_last')",
#  "('9128285J Govt', 'px_last')",
#  "('9128285M Govt', 'px_last')",
#  "('9128285P Govt', 'px_last')",
#  "('9128285R Govt', 'px_last')",
#  "('9128285S Govt', 'px_last')",
#  "('9128285T Govt', 'px_last')",
#  "('9128285U Govt', 'px_last')",
#  "('9128286A Govt', 'px_last')",
#  "('9128286B Govt', 'px_last')",
#  "('9128286G Govt', 'px_last')",
#  "('9128286H Govt', 'px_last')",
#  "('9128286L Govt', 'px_last')",
#  "('9128286S Govt', 'px_last')",
#  "('9128286T Govt', 'px_last')",
#  "('9128286Y Govt', 'px_last')",
#  "('9128286Z Govt', 'px_last')",
#  "('9128287B Govt', 'px_last')",
#  "('912828A3 Govt', 'px_last')",
#  "('912828A4 Govt', 'px_last')",
#  "('912828A7 Govt', 'px_last')",
#  "('912828B6 Govt', 'px_last')",
#  "('912828C2 Govt', 'px_last')",
#  "('912828C6 Govt', 'px_last')",
#  "('912828D5 Govt', 'px_last')",
#  "('912828D8 Govt', 'px_last')",
#  "('912828D9 Govt', 'px_last')",
#  "('912828F2 Govt', 'px_last')",
#  "('912828F3 Govt', 'px_last')",
#  "('912828F9 Govt', 'px_last')",
#  "('912828G3 Govt', 'px_last')",
#  "('912828G6 Govt', 'px_last')",
#  "('912828G7 Govt', 'px_last')",
#  "('912828G8 Govt', 'px_last')",
#  "('912828G9 Govt', 'px_last')",
#  "('912828GH Govt', 'px_last')",
#  "('912828GM Govt', 'px_last')",
#  "('912828GS Govt', 'px_last')",
#  "('912828GW Govt', 'px_last')",
#  "('912828HA Govt', 'px_last')",
#  "('912828HE Govt', 'px_last')",
#  "('912828HH Govt', 'px_last')",
#  "('912828HM Govt', 'px_last')",
#  "('912828HR Govt', 'px_last')",
#  "('912828HV Govt', 'px_last')",
#  "('912828HZ Govt', 'px_last')",
#  "('912828J2 Govt', 'px_last')",
#  "('912828J5 Govt', 'px_last')",
#  "('912828J6 Govt', 'px_last')",
#  "('912828J7 Govt', 'px_last')",
#  "('912828J8 Govt', 'px_last')",
#  "('912828JD Govt', 'px_last')",
#  "('912828JH Govt', 'px_last')",
#  "('912828JM Govt', 'px_last')",
#  "('912828JR Govt', 'px_last')",
#  "('912828JW Govt', 'px_last')",
#  "('912828K7 Govt', 'px_last')",
#  "('912828KD Govt', 'px_last')",
#  "('912828KJ Govt', 'px_last')",
#  "('912828KQ Govt', 'px_last')",
#  "('912828KY Govt', 'px_last')",
#  "('912828L2 Govt', 'px_last')",
#  "('912828L3 Govt', 'px_last')",
#  "('912828L4 Govt', 'px_last')",
#  "('912828L5 Govt', 'px_last')",
#  "('912828L6 Govt', 'px_last')",
#  "('912828LJ Govt', 'px_last')",
#  "('912828LK Govt', 'px_last')",
#  "('912828LQ Govt', 'px_last')",
#  "('912828LY Govt', 'px_last')",
#  "('912828LZ Govt', 'px_last')",
#  "('912828M4 Govt', 'px_last')",
#  "('912828M5 Govt', 'px_last')",
#  "('912828M8 Govt', 'px_last')",
#  "('912828M9 Govt', 'px_last')",
#  "('912828MB Govt', 'px_last')",
#  "('912828ME Govt', 'px_last')",
#  "('912828MP Govt', 'px_last')",
#  "('912828MR Govt', 'px_last')",
#  "('912828MS Govt', 'px_last')",
#  "('912828MT Govt', 'px_last')",
#  "('912828MV Govt', 'px_last')",
#  "('912828MW Govt', 'px_last')",
#  "('912828N2 Govt', 'px_last')",
#  "('912828N3 Govt', 'px_last')",
#  "('912828N4 Govt', 'px_last')",
#  "('912828NA Govt', 'px_last')",
#  "('912828ND Govt', 'px_last')",
#  "('912828NF Govt', 'px_last')",
#  "('912828NG Govt', 'px_last')",
#  "('912828NL Govt', 'px_last')",
#  "('912828NT Govt', 'px_last')",
#  "('912828NV Govt', 'px_last')",
#  "('912828NZ Govt', 'px_last')",
#  "('912828P4 Govt', 'px_last')",
#  "('912828P8 Govt', 'px_last')",
#  "('912828PC Govt', 'px_last')",
#  "('912828PJ Govt', 'px_last')",
#  "('912828PL Govt', 'px_last')",
#  "('912828PM Govt', 'px_last')",
#  "('912828PX Govt', 'px_last')",
#  "('912828PY Govt', 'px_last')",
#  "('912828PZ Govt', 'px_last')",
#  "('912828QA Govt', 'px_last')",
#  "('912828QJ Govt', 'px_last')",
#  "('912828QN Govt', 'px_last')",
#  "('912828QP Govt', 'px_last')",
#  "('912828QR Govt', 'px_last')",
#  "('912828R3 Govt', 'px_last')",
#  "('912828R6 Govt', 'px_last')",
#  "('912828R7 Govt', 'px_last')",
#  "('912828RC Govt', 'px_last')",
#  "('912828RE Govt', 'px_last')",
#  "('912828RF Govt', 'px_last')",
#  "('912828RH Govt', 'px_last')",
#  "('912828RJ Govt', 'px_last')",
#  "('912828RR Govt', 'px_last')",
#  "('912828RU Govt', 'px_last')",
#  "('912828RX Govt', 'px_last')",
#  "('912828SF Govt', 'px_last')",
#  "('912828SJ Govt', 'px_last')",
#  "('912828SM Govt', 'px_last')",
#  "('912828SV Govt', 'px_last')",
#  "('912828SY Govt', 'px_last')",
#  "('912828TB Govt', 'px_last')",
#  "('912828TJ Govt', 'px_last')",
#  "('912828TM Govt', 'px_last')",
#  "('912828TS Govt', 'px_last')",
#  "('912828TY Govt', 'px_last')",
#  "('912828U2 Govt', 'px_last')",
#  "('912828U6 Govt', 'px_last')",
#  "('912828UA Govt', 'px_last')",
#  "('912828UE Govt', 'px_last')",
#  "('912828UN Govt', 'px_last')",
#  "('912828UR Govt', 'px_last')",
#  "('912828UU Govt', 'px_last')",
#  "('912828V9 Govt', 'px_last')",
#  "('912828VB Govt', 'px_last')",
#  "('912828VE Govt', 'px_last')",
#  "('912828VK Govt', 'px_last')",
#  "('912828VS Govt', 'px_last')",
#  "('912828VV Govt', 'px_last')",
#  "('912828W5 Govt', 'px_last')",
#  "('912828W6 Govt', 'px_last')",
#  "('912828W7 Govt', 'px_last')",
#  "('912828W8 Govt', 'px_last')",
#  "('912828WE Govt', 'px_last')",
#  "('912828WJ Govt', 'px_last')",
#  "('912828WL Govt', 'px_last')",
#  "('912828WP Govt', 'px_last')",
#  "('912828WS Govt', 'px_last')",
#  "('912828WY Govt', 'px_last')",
#  "('912828WZ Govt', 'px_last')",
#  "('912828X8 Govt', 'px_last')",
#  "('912828XB Govt', 'px_last')",
#  "('912828XD Govt', 'px_last')",
#  "('912828XE Govt', 'px_last')",
#  "('912828XF Govt', 'px_last')",
#  "('912828XG Govt', 'px_last')",
#  "('912828XH Govt', 'px_last')",
#  "('912828XQ Govt', 'px_last')",
#  "('912828XR Govt', 'px_last')",
#  "('912828XT Govt', 'px_last')",
#  "('912828XY Govt', 'px_last')",
#  "('912828XZ Govt', 'px_last')",
#  "('912828Y7 Govt', 'px_last')",
#  "('912828Y9 Govt', 'px_last')",
#  "('912828YB Govt', 'px_last')",
#  "('912828YE Govt', 'px_last')",
#  "('912828YF Govt', 'px_last')",
#  "('912828YH Govt', 'px_last')",
#  "('912828YS Govt', 'px_last')",
#  "('912828YV Govt', 'px_last')",
#  "('912828YW Govt', 'px_last')",
#  "('912828YX Govt', 'px_last')",
#  "('912828YY Govt', 'px_last')",
#  "('912828Z9 Govt', 'px_last')",
#  "('912828ZC Govt', 'px_last')",
#  "('912828ZF Govt', 'px_last')",
#  "('912828ZQ Govt', 'px_last')",
#  "('912828ZT Govt', 'px_last')",
#  "('91282CAE Govt', 'px_last')",
#  "('91282CAJ Govt', 'px_last')",
#  "('91282CAV Govt', 'px_last')",
#  "('91282CAZ Govt', 'px_last')",
#  "('91282CBQ Govt', 'px_last')",
#  "('91282CCB Govt', 'px_last')",
#  "('91282CCF Govt', 'px_last')",
#  "('91282CCS Govt', 'px_last')",
#  "('91282CCW Govt', 'px_last')",
#  "('91282CDJ Govt', 'px_last')",
#  "('91282CDK Govt', 'px_last')",
#  "('91282CDY Govt', 'px_last')",
#  "('91282CEC Govt', 'px_last')",
#  "('91282CED Govt', 'px_last')",
#  "('91282CEE Govt', 'px_last')",
#  "('91282CEF Govt', 'px_last')",
#  "('91282CEG Govt', 'px_last')",
#  "('91282CEM Govt', 'px_last')",
#  "('91282CEP Govt', 'px_last')",
#  "('91282CET Govt', 'px_last')",
#  "('91282CEU Govt', 'px_last')",
#  "('91282CEV Govt', 'px_last')",
#  "('91282CEW Govt', 'px_last')",
#  "('91282CEX Govt', 'px_last')",
#  "('91282CFF Govt', 'px_last')",
#  "('91282CFK Govt', 'px_last')",
#  "('91282CFL Govt', 'px_last')",
#  "('91282CFM Govt', 'px_last')",
#  "('91282CFN Govt', 'px_last')",
#  "('91282CFT Govt', 'px_last')",
#  "('91282CFV Govt', 'px_last')",
#  "('91282CFZ Govt', 'px_last')",
#  "('91282CGA Govt', 'px_last')",
#  "('91282CGB Govt', 'px_last')",
#  "('91282CGD Govt', 'px_last')",
#  "('91282CGM Govt', 'px_last')",
#  "('91282CGP Govt', 'px_last')",
#  "('91282CGQ Govt', 'px_last')",
#  "('91282CGR Govt', 'px_last')",
#  "('91282CGS Govt', 'px_last')",
#  "('91282CGT Govt', 'px_last')",
#  "('91282CGU Govt', 'px_last')",
#  "('91282CHE Govt', 'px_last')",
#  "('91282CHF Govt', 'px_last')",
#  "('91282CHH Govt', 'px_last')",
#  "('91282CHJ Govt', 'px_last')",
#  "('91282CHK Govt', 'px_last')",
#  "('91282CHL Govt', 'px_last')",
#  "('91282CHR Govt', 'px_last')",
#  "('91282CHW Govt', 'px_last')",
#  "('91282CHX Govt', 'px_last')",
#  "('91282CHY Govt', 'px_last')",
#  "('91282CHZ Govt', 'px_last')",
#  "('91282CJB Govt', 'px_last')",
#  "('91282CJG Govt', 'px_last')",
#  "('91282CJN Govt', 'px_last')",
#  "('91282CJP Govt', 'px_last')",
#  "('91282CJQ Govt', 'px_last')",
#  "('91282CJS Govt', 'px_last')",
#  "('91282CJX Govt', 'px_last')",
#  "('91282CKC Govt', 'px_last')",
#  "('91282CKD Govt', 'px_last')",
#  "('91282CKE Govt', 'px_last')",
#  "('91282CKF Govt', 'px_last')",
#  "('91282CKN Govt', 'px_last')",
#  "('91282CKT Govt', 'px_last')",
#  "('91282CKU Govt', 'px_last')",
#  "('91282CKV Govt', 'px_last')",
#  "('91282CKW Govt', 'px_last')",
#  "('91282CKY Govt', 'px_last')",
#  "('91282CLK Govt', 'px_last')",
#  "('91282CLM Govt', 'px_last')",
#  "('91282CLU Govt', 'px_last')",
#  "('91282CLZ Govt', 'px_last')",
#  "('91282CMA Govt', 'px_last')",
#  "('91282CMB Govt', 'px_last')",
#  "('91282CMC Govt', 'px_last')",
#  "('91282CME Govt', 'px_last')",
#  "('91282CMK Govt', 'px_last')",
#  "('91282CMS Govt', 'px_last')",
#  "('91282CMT Govt', 'px_last')",
#  "('91282CNA Govt', 'px_last')",
#  "('91282CNF Govt', 'px_last')",
#  "('91282CNG Govt', 'px_last')",
#  "('91282CNJ Govt', 'px_last')",
#  "('91282CNR Govt', 'px_last')",
#  "('91282CNW Govt', 'px_last')",
#  "('91282CNX Govt', 'px_last')",
#  "('91282CPQ Govt', 'px_last')",
#  "('91282CPY Govt', 'px_last')",
#  'Date']

# %%
cols_needed = [
    "('USSOD CMPN Curncy', 'px_last')",
    "('USSOB CMPN Curncy', 'px_last')",
    "('USSOC CMPN Curncy', 'px_last')",
    "('USSOF CMPN Curncy', 'px_last')",
    "('USSOE CMPN Curncy', 'px_last')",
    "('USSOI CMPN Curncy', 'px_last')",
]

df_usso = df.select(cols_needed)
df_usso
# Out:
# shape: (4_216, 6)
# ┌────────────────┬────────────────┬────────────────┬───────────────┬───────────────┬───────────────┐
# │ ('USSOD CMPN   ┆ ('USSOB CMPN   ┆ ('USSOC CMPN   ┆ ('USSOF CMPN  ┆ ('USSOE CMPN  ┆ ('USSOI CMPN  │
# │ Curncy',       ┆ Curncy',       ┆ Curncy',       ┆ Curncy',      ┆ Curncy',      ┆ Curncy',      │
# │ 'px_last…      ┆ 'px_last…      ┆ 'px_last…      ┆ 'px_last…     ┆ 'px_last…     ┆ 'px_last…     │
# │ ---            ┆ ---            ┆ ---            ┆ ---           ┆ ---           ┆ ---           │
# │ f64            ┆ f64            ┆ f64            ┆ f64           ┆ f64           ┆ f64           │
# ╞════════════════╪════════════════╪════════════════╪═══════════════╪═══════════════╪═══════════════╡
# │ 0.178          ┆ 0.146          ┆ 0.162          ┆ 0.215         ┆ 0.1965        ┆ 0.3205        │
# │ 0.1655         ┆ 0.14           ┆ 0.155          ┆ 0.2055        ┆ 0.1845        ┆ 0.293         │
# │ 0.1595         ┆ 0.137          ┆ 0.146          ┆ 0.1895        ┆ 0.172         ┆ 0.2795        │
# │ 0.1595         ┆ 0.135          ┆ 0.145          ┆ 0.192         ┆ 0.171         ┆ 0.285         │
# │ 0.1625         ┆ 0.137          ┆ 0.143          ┆ 0.185         ┆ 0.171         ┆ 0.2625        │
# │ …              ┆ …              ┆ …              ┆ …             ┆ …             ┆ …             │
# │ null           ┆ null           ┆ null           ┆ null          ┆ null          ┆ null          │
# │ null           ┆ null           ┆ null           ┆ null          ┆ null          ┆ null          │
# │ null           ┆ null           ┆ null           ┆ null          ┆ null          ┆ null          │
# │ null           ┆ null           ┆ null           ┆ null          ┆ null          ┆ null          │
# │ null           ┆ null           ┆ null           ┆ null          ┆ null          ┆ null          │
# └────────────────┴────────────────┴────────────────┴───────────────┴───────────────┴───────────────┘

# %%
# Select columns whose names contain either 'fut_dlv_dt_first' or 'fut_dlv_dt_last'
cols = [col for col in df.columns if 'fut_dlv_dt_first' in str(col) or 'fut_dlv_dt_last' in str(col)]
df_dates = df.select(cols)
df_dates
# Out:
# shape: (0, 0)
# ┌┐
# ╞╡
# └┘

# %%
df_crsp = pl.read_parquet("../data_manual/TFZ_IRR.parquet")
df_crsp
# Out:
# shape: (1_203_074, 18)
# ┌───────────┬─────────────┬──────────┬────────────┬───┬────────────┬────────────┬──────────┬───────┐
# │ kytreasno ┆ kycrspid    ┆ tcusip   ┆ caldt      ┆ … ┆ tdbid      ┆ tdask      ┆ tdyld    ┆ itype │
# │ ---       ┆ ---         ┆ ---      ┆ ---        ┆   ┆ ---        ┆ ---        ┆ ---      ┆ ---   │
# │ f64       ┆ str         ┆ str      ┆ datetime[n ┆   ┆ f64        ┆ f64        ┆ f64      ┆ f64   │
# │           ┆             ┆          ┆ s]         ┆   ┆            ┆            ┆          ┆       │
# ╞═══════════╪═════════════╪══════════╪════════════╪═══╪════════════╪════════════╪══════════╪═══════╡
# │ 204043.0  ┆ 20150215.11 ┆ 912810DP ┆ 2010-01-04 ┆ … ┆ 141.359375 ┆ 141.390625 ┆ 0.00007  ┆ 1.0   │
# │           ┆ 1250        ┆          ┆ 00:00:00   ┆   ┆            ┆            ┆          ┆       │
# │ 204043.0  ┆ 20150215.11 ┆ 912810DP ┆ 2010-01-05 ┆ … ┆ 141.796875 ┆ 141.828125 ┆ 0.000068 ┆ 1.0   │
# │           ┆ 1250        ┆          ┆ 00:00:00   ┆   ┆            ┆            ┆          ┆       │
# │ 204043.0  ┆ 20150215.11 ┆ 912810DP ┆ 2010-01-06 ┆ … ┆ 141.578125 ┆ 141.625    ┆ 0.000069 ┆ 1.0   │
# │           ┆ 1250        ┆          ┆ 00:00:00   ┆   ┆            ┆            ┆          ┆       │
# │ 204043.0  ┆ 20150215.11 ┆ 912810DP ┆ 2010-01-07 ┆ … ┆ 141.484375 ┆ 141.515625 ┆ 0.000069 ┆ 1.0   │
# │           ┆ 1250        ┆          ┆ 00:00:00   ┆   ┆            ┆            ┆          ┆       │
# │ 204043.0  ┆ 20150215.11 ┆ 912810DP ┆ 2010-01-08 ┆ … ┆ 141.515625 ┆ 141.5625   ┆ 0.000069 ┆ 1.0   │
# │           ┆ 1250        ┆          ┆ 00:00:00   ┆   ┆            ┆            ┆          ┆       │
# │ …         ┆ …           ┆ …        ┆ …          ┆ … ┆ …          ┆ …          ┆ …        ┆ …     │
# │ 208514.0  ┆ 20310131.20 ┆ 91282CPW ┆ 2026-01-28 ┆ … ┆ 99.609375  ┆ 99.617188  ┆ 0.000104 ┆ 2.0   │
# │           ┆ 3750        ┆          ┆ 00:00:00   ┆   ┆            ┆            ┆          ┆       │
# │ 208514.0  ┆ 20310131.20 ┆ 91282CPW ┆ 2026-01-29 ┆ … ┆ 99.703125  ┆ 99.710938  ┆ 0.000103 ┆ 2.0   │
# │           ┆ 3750        ┆          ┆ 00:00:00   ┆   ┆            ┆            ┆          ┆       │
# │ 208514.0  ┆ 20310131.20 ┆ 91282CPW ┆ 2026-01-30 ┆ … ┆ 99.757812  ┆ 99.765625  ┆ 0.000103 ┆ 2.0   │
# │           ┆ 3750        ┆          ┆ 00:00:00   ┆   ┆            ┆            ┆          ┆       │
# │ 208515.0  ┆ 20330131.20 ┆ 91282CPY ┆ 2026-01-29 ┆ … ┆ 99.863281  ┆ 99.921875  ┆ 0.000109 ┆ 2.0   │
# │           ┆ 4000        ┆          ┆ 00:00:00   ┆   ┆            ┆            ┆          ┆       │
# │ 208515.0  ┆ 20330131.20 ┆ 91282CPY ┆ 2026-01-30 ┆ … ┆ 99.828125  ┆ 99.84375   ┆ 0.000109 ┆ 2.0   │
# │           ┆ 4000        ┆          ┆ 00:00:00   ┆   ┆            ┆            ┆          ┆       │
# └───────────┴─────────────┴──────────┴────────────┴───┴────────────┴────────────┴──────────┴───────┘

# %%
df_crsp_cusip = df_crsp.filter(
    (pl.col("tcusip") == "91282CJB") & (pl.col("caldt") == pl.date(2023, 9, 29))
)
df_crsp_cusip
# Out:
# shape: (1, 18)
# ┌───────────┬──────────────┬──────────┬─────────────┬───┬───────────┬───────────┬──────────┬───────┐
# │ kytreasno ┆ kycrspid     ┆ tcusip   ┆ caldt       ┆ … ┆ tdbid     ┆ tdask     ┆ tdyld    ┆ itype │
# │ ---       ┆ ---          ┆ ---      ┆ ---         ┆   ┆ ---       ┆ ---       ┆ ---      ┆ ---   │
# │ f64       ┆ str          ┆ str      ┆ datetime[ns ┆   ┆ f64       ┆ f64       ┆ f64      ┆ f64   │
# │           ┆              ┆          ┆ ]           ┆   ┆           ┆           ┆          ┆       │
# ╞═══════════╪══════════════╪══════════╪═════════════╪═══╪═══════════╪═══════════╪══════════╪═══════╡
# │ 208116.0  ┆ 20250930.205 ┆ 91282CJB ┆ 2023-09-29  ┆ … ┆ 99.898438 ┆ 99.929688 ┆ 0.000136 ┆ 2.0   │
# │           ┆ 000          ┆          ┆ 00:00:00    ┆   ┆           ┆           ┆          ┆       │
# └───────────┴──────────────┴──────────┴─────────────┴───┴───────────┴───────────┴──────────┴───────┘

# %%
df_crsp.select("tcusip").unique()
# Out:
# shape: (1_097, 1)
# ┌──────────┐
# │ tcusip   │
# │ ---      │
# │ str      │
# ╞══════════╡
# │ 91282CHW │
# │ 912828YD │
# │ 91282CEW │
# │ 912828RX │
# │ 91282CDB │
# │ …        │
# │ 912828J2 │
# │ 91282CHK │
# │ 912828T3 │
# │ 912828C2 │
# │ 912810TD │
# └──────────┘

# %%
# Implied repo from calc_spread.py (first deferred contract, volume > 0)
df_irr = pl.read_parquet("../data_manual/implied_repo_first_deferred.parquet")

# %%
import numpy as np
import pandas as pd

tenors = ["2Y", "5Y", "10Y", "20Y", "30Y"]
pdf = df_irr.to_pandas()
dates = pd.to_datetime(pdf["Date"]).dt.normalize()
day = dates.dt.day
last_day = (dates + pd.offsets.MonthEnd(0)).dt.day
in_first_3 = (day <= 3).values
in_last_3 = (day >= last_day - 2).values
in_first_or_last_3 = in_first_3 | in_last_3

total_spikes = 0
spikes_in_window = 0
for col in tenors:
    s = pdf[col].dropna()
    if len(s) < 2:
        continue
    mean, std = s.mean(), s.std()
    if std == 0:
        continue
    is_spike = (~pdf[col].isna()) & (np.abs(pdf[col] - mean) > 3 * std)
    total_spikes += is_spike.sum()
    spikes_in_window += (is_spike & in_first_or_last_3).sum()

pct = 100 * spikes_in_window / total_spikes if total_spikes > 0 else float("nan")
print(f"Percentage of big spikes (>3 sd) in first or last 3 days of month: {pct:.2f}%")
print(f"  (spikes in window: {spikes_in_window}, total spikes: {total_spikes})")
# Out:
# Percentage of big spikes (>3 sd) in first or last 3 days of month: 14.96%
#   (spikes in window: 19, total spikes: 127)

# %%
# List the top 10 biggest spikes in absolute value across all tenors (excluding NaN)
top_spikes = []
for col in tenors:
    s = pdf[["Date", col]].dropna()
    if len(s) == 0:
        continue
    mean = s[col].mean()
    std = s[col].std()
    s["abs_dev"] = (s[col] - mean).abs()
    s["tenor"] = col
    top_spikes.append(s)

if top_spikes:
    all_spikes = pd.concat(top_spikes, ignore_index=True)
    top10 = all_spikes.sort_values("abs_dev", ascending=False).head(20)
    print("Top 10 biggest spikes (by absolute deviation from mean, across all tenors):")
    display(top10[["Date", "tenor", col, "abs_dev"]])
else:
    print("No valid spikes found.")
# Out:
# Top 10 biggest spikes (by absolute deviation from mean, across all tenors):
#             Date tenor         30Y      abs_dev
# 13568 2023-03-15   20Y         NaN  1364.390933
# 17348 2023-03-15   30Y  1335.53593  1194.540865
# 10625 2023-03-15   10Y         NaN  1019.724072
# 10693 2023-06-21   10Y         NaN   984.305825
# 13084 2020-03-17   20Y         NaN   976.088244
# 13414 2022-03-21   20Y         NaN   972.197733
# 10692 2023-06-20   10Y         NaN   970.600550
# 13803 2024-06-03   20Y         NaN   965.920291
# 10684 2023-06-07   10Y         NaN   940.964408
# 10690 2023-06-15   10Y         NaN   926.102413
# 10686 2023-06-09   10Y         NaN   921.400541
# 10675 2023-05-24   10Y         NaN   912.093106
# 10780 2023-10-25   10Y         NaN   911.820324
# 10778 2023-10-23   10Y         NaN   910.511053
# 10689 2023-06-14   10Y         NaN   909.156118
# 10681 2023-06-02   10Y         NaN   902.953418
# 10741 2023-08-29   10Y         NaN   901.841065
# 10781 2023-10-26   10Y         NaN   899.078171
# 10679 2023-05-31   10Y         NaN   898.913129
# 10775 2023-10-18   10Y         NaN   897.648434

# %%
df_irr.head(20)
# Out:
# shape: (20, 6)
# ┌────────────┬────────────┬────────────┬────────────┬────────────┬─────────────────────┐
# │ 2Y         ┆ 5Y         ┆ 10Y        ┆ 20Y        ┆ 30Y        ┆ Date                │
# │ ---        ┆ ---        ┆ ---        ┆ ---        ┆ ---        ┆ ---                 │
# │ f64        ┆ f64        ┆ f64        ┆ f64        ┆ f64        ┆ datetime[ns]        │
# ╞════════════╪════════════╪════════════╪════════════╪════════════╪═════════════════════╡
# │ null       ┆ null       ┆ -33.919016 ┆ null       ┆ -22.112709 ┆ 2010-01-04 00:00:00 │
# │ -20.631517 ┆ null       ┆ -3.804251  ┆ null       ┆ 47.077476  ┆ 2010-01-05 00:00:00 │
# │ -17.274153 ┆ null       ┆ 9.190209   ┆ null       ┆ 46.854757  ┆ 2010-01-06 00:00:00 │
# │ -7.387119  ┆ null       ┆ -12.428141 ┆ null       ┆ 22.212171  ┆ 2010-01-07 00:00:00 │
# │ -8.577122  ┆ 32.859252  ┆ 12.253219  ┆ null       ┆ 66.442789  ┆ 2010-01-08 00:00:00 │
# │ …          ┆ …          ┆ …          ┆ …          ┆ …          ┆ …                   │
# │ -17.561054 ┆ -15.521048 ┆ -34.114003 ┆ -24.125196 ┆ -5.416219  ┆ 2010-01-26 00:00:00 │
# │ -0.311658  ┆ 12.026964  ┆ -16.467892 ┆ 54.177845  ┆ 19.050945  ┆ 2010-01-27 00:00:00 │
# │ -13.734647 ┆ -13.061104 ┆ -50.301728 ┆ -60.765638 ┆ -38.489547 ┆ 2010-01-28 00:00:00 │
# │ -15.917368 ┆ -30.54956  ┆ -53.444121 ┆ -93.560115 ┆ -62.108128 ┆ 2010-01-29 00:00:00 │
# │ -14.169868 ┆ -2.492935  ┆ -32.708875 ┆ -13.389818 ┆ -8.169892  ┆ 2010-02-01 00:00:00 │
# └────────────┴────────────┴────────────┴────────────┴────────────┴─────────────────────┘

# %%
df_irr.tail()
# Out:
# shape: (5, 6)
# ┌────────────┬────────────┬────────────┬────────────┬────────────┬─────────────────────┐
# │ 2Y         ┆ 5Y         ┆ 10Y        ┆ 20Y        ┆ 30Y        ┆ Date                │
# │ ---        ┆ ---        ┆ ---        ┆ ---        ┆ ---        ┆ ---                 │
# │ f64        ┆ f64        ┆ f64        ┆ f64        ┆ f64        ┆ datetime[ns]        │
# ╞════════════╪════════════╪════════════╪════════════╪════════════╪═════════════════════╡
# │ 377.278851 ┆ 381.143591 ┆ 361.460332 ┆ 355.753155 ┆ 334.049406 ┆ 2026-01-26 00:00:00 │
# │ 376.723736 ┆ 390.259684 ┆ 374.162708 ┆ 403.477121 ┆ 379.086285 ┆ 2026-01-27 00:00:00 │
# │ 375.557475 ┆ 370.436156 ┆ 352.191152 ┆ 351.444518 ┆ 344.150963 ┆ 2026-01-28 00:00:00 │
# │ 380.837059 ┆ 388.969909 ┆ 380.787644 ┆ 374.65858  ┆ 360.572226 ┆ 2026-01-29 00:00:00 │
# │ 376.883894 ┆ 386.95362  ┆ 386.481368 ┆ 444.322594 ┆ 405.509946 ┆ 2026-01-30 00:00:00 │
# └────────────┴────────────┴────────────┴────────────┴────────────┴─────────────────────┘

# %%
import polars as pl

# Ensure the 'Date' column is of datetime type if needed
if "Date" in df_irr.columns:
    if df_irr.schema["Date"] != pl.Datetime:
        df_irr = df_irr.with_columns(pl.col("Date").str.to_datetime().alias("Date"))
else:
    # Try typical datetime column names: we expect the date column is called 'Date'
    raise ValueError("No 'Date' column found in df_irr.")

# Extract year, month, and day for grouping/comparison
df_display = df_irr.with_columns([
    pl.col("Date").dt.year().alias("year"),
    pl.col("Date").dt.month().alias("month"),
    pl.col("Date").dt.day().alias("day")
])

# For each year/month group, get first 3 and last 3 days
out = []
for (year, month), group in df_display.group_by(["year", "month"], maintain_order=True):
    days_sorted = group.sort("day")
    first_3 = days_sorted.head(3)
    last_3 = days_sorted.tail(3)
    out.append(first_3)
    out.append(last_3)

display_df = pl.concat(out).sort(["year", "month", "day"])
display_df = display_df.drop(["year", "month", "day"])
display_df
# Out:
# shape: (1_158, 6)
# ┌────────────┬────────────┬────────────┬────────────┬────────────┬─────────────────────┐
# │ 2Y         ┆ 5Y         ┆ 10Y        ┆ 20Y        ┆ 30Y        ┆ Date                │
# │ ---        ┆ ---        ┆ ---        ┆ ---        ┆ ---        ┆ ---                 │
# │ f64        ┆ f64        ┆ f64        ┆ f64        ┆ f64        ┆ datetime[ns]        │
# ╞════════════╪════════════╪════════════╪════════════╪════════════╪═════════════════════╡
# │ null       ┆ null       ┆ -33.919016 ┆ null       ┆ -22.112709 ┆ 2010-01-04 00:00:00 │
# │ -20.631517 ┆ null       ┆ -3.804251  ┆ null       ┆ 47.077476  ┆ 2010-01-05 00:00:00 │
# │ -17.274153 ┆ null       ┆ 9.190209   ┆ null       ┆ 46.854757  ┆ 2010-01-06 00:00:00 │
# │ -0.311658  ┆ 12.026964  ┆ -16.467892 ┆ 54.177845  ┆ 19.050945  ┆ 2010-01-27 00:00:00 │
# │ -13.734647 ┆ -13.061104 ┆ -50.301728 ┆ -60.765638 ┆ -38.489547 ┆ 2010-01-28 00:00:00 │
# │ …          ┆ …          ┆ …          ┆ …          ┆ …          ┆ …                   │
# │ 371.803035 ┆ 369.714768 ┆ 356.152061 ┆ 362.845039 ┆ 327.843352 ┆ 2026-01-05 00:00:00 │
# │ 366.433689 ┆ 361.483782 ┆ 349.260692 ┆ null       ┆ 321.897647 ┆ 2026-01-06 00:00:00 │
# │ 375.557475 ┆ 370.436156 ┆ 352.191152 ┆ 351.444518 ┆ 344.150963 ┆ 2026-01-28 00:00:00 │
# │ 380.837059 ┆ 388.969909 ┆ 380.787644 ┆ 374.65858  ┆ 360.572226 ┆ 2026-01-29 00:00:00 │
# │ 376.883894 ┆ 386.95362  ┆ 386.481368 ┆ 444.322594 ┆ 405.509946 ┆ 2026-01-30 00:00:00 │
# └────────────┴────────────┴────────────┴────────────┴────────────┴─────────────────────┘

# %%
df_irr.null_count()
# Out:
# shape: (1, 6)
# ┌─────┬─────┬─────┬──────┬─────┬──────┐
# │ 2Y  ┆ 5Y  ┆ 10Y ┆ 20Y  ┆ 30Y ┆ Date │
# │ --- ┆ --- ┆ --- ┆ ---  ┆ --- ┆ ---  │
# │ u32 ┆ u32 ┆ u32 ┆ u32  ┆ u32 ┆ u32  │
# ╞═════╪═════╪═════╪══════╪═════╪══════╡
# │ 339 ┆ 288 ┆ 89  ┆ 1224 ┆ 85  ┆ 0    │
# └─────┴─────┴─────┴──────┴─────┴──────┘

# %%
df_spreads = pl.read_parquet("../data_manual/arbitrage_spreads.parquet")

# %%
df_spreads
# Out:
# shape: (4_018, 6)
# ┌────────────┬───────────┬────────────┬────────────┬────────────┬─────────────────────┐
# │ 2Y         ┆ 5Y        ┆ 10Y        ┆ 20Y        ┆ 30Y        ┆ Date                │
# │ ---        ┆ ---       ┆ ---        ┆ ---        ┆ ---        ┆ ---                 │
# │ f64        ┆ f64       ┆ f64        ┆ f64        ┆ f64        ┆ datetime[ns]        │
# ╞════════════╪═══════════╪════════════╪════════════╪════════════╪═════════════════════╡
# │ null       ┆ null      ┆ -55.023674 ┆ null       ┆ -43.217367 ┆ 2010-01-04 00:00:00 │
# │ -40.663709 ┆ null      ┆ -23.836443 ┆ null       ┆ 27.045285  ┆ 2010-01-05 00:00:00 │
# │ -35.735112 ┆ null      ┆ -9.27075   ┆ null       ┆ 28.393798  ┆ 2010-01-06 00:00:00 │
# │ -25.931228 ┆ null      ┆ -30.97225  ┆ null       ┆ 3.668062   ┆ 2010-01-07 00:00:00 │
# │ -26.501779 ┆ 14.934594 ┆ -5.671439  ┆ null       ┆ 48.518132  ┆ 2010-01-08 00:00:00 │
# │ …          ┆ …         ┆ …          ┆ …          ┆ …          ┆ …                   │
# │ 15.902865  ┆ 18.661331 ┆ -1.021928  ┆ -5.622831  ┆ -27.326581 ┆ 2026-01-26 00:00:00 │
# │ 15.911377  ┆ 28.18464  ┆ 12.087665  ┆ 42.664762  ┆ 18.273926  ┆ 2026-01-27 00:00:00 │
# │ 13.824105  ┆ 7.530074  ┆ -9.542218  ┆ -10.288852 ┆ -17.582407 ┆ 2026-01-28 00:00:00 │
# │ 18.758026  ┆ 26.890876 ┆ 18.708612  ┆ 13.968687  ┆ -0.117667  ┆ 2026-01-29 00:00:00 │
# │ 16.469264  ┆ 24.895866 ┆ 26.066738  ┆ 83.907964  ┆ 45.095316  ┆ 2026-01-30 00:00:00 │
# └────────────┴───────────┴────────────┴────────────┴────────────┴─────────────────────┘

# %%
mine = df_spreads['2Y']

# %%
import matplotlib.pyplot as plt

import polars as pl

# Check dtype and only convert to datetime if needed
date_dtype = df_spreads.schema["Date"]

# In polars, the dtype will be pl.Datetime if already correct.
if date_dtype != pl.Datetime:
    df_spreads = df_spreads.with_columns(
        pl.col("Date").str.to_datetime().alias("Date")
    )

# Collect data for plotting using polars (avoid pandas conversion)
date = df_spreads["Date"].to_numpy()
columns = [col for col in df_spreads.columns if col != "Date"]

plt.figure(figsize=(12, 6))
for col in columns:
    plt.plot(date, df_spreads[col].to_numpy(), label=col)
plt.xlabel("Date")
plt.ylabel("Spread")
plt.title("Arbitrage Spreads Over Time")
plt.legend()
plt.tight_layout()
plt.show()

# %%
df_spreads_mean = df_spreads.mean()
df_spreads_median = df_spreads.median()
print("Column means:")
print(df_spreads_mean)
print("\nColumn medians:")
print(df_spreads_median)
# Out:
# Column means:
# shape: (1, 6)
# ┌───────────┬──────────┬───────────┬────────────┬──────────┬───────────────────────────────┐
# │ 2Y        ┆ 5Y       ┆ 10Y       ┆ 20Y        ┆ 30Y      ┆ Date                          │
# │ ---       ┆ ---      ┆ ---       ┆ ---        ┆ ---      ┆ ---                           │
# │ f64       ┆ f64      ┆ f64       ┆ f64        ┆ f64      ┆ datetime[ns]                  │
# ╞═══════════╪══════════╪═══════════╪════════════╪══════════╪═══════════════════════════════╡
# │ -3.819745 ┆ 9.249675 ┆ 20.384722 ┆ -13.068013 ┆ -8.79209 ┆ 2018-01-14 05:20:45.395718912 │
# └───────────┴──────────┴───────────┴────────────┴──────────┴───────────────────────────────┘
#
# Column medians:
# shape: (1, 6)
# ┌───────────┬──────────┬──────────┬───────────┬───────────┬─────────────────────┐
# │ 2Y        ┆ 5Y       ┆ 10Y      ┆ 20Y       ┆ 30Y       ┆ Date                │
# │ ---       ┆ ---      ┆ ---      ┆ ---       ┆ ---       ┆ ---                 │
# │ f64       ┆ f64      ┆ f64      ┆ f64       ┆ f64       ┆ datetime[ns]        │
# ╞═══════════╪══════════╪══════════╪═══════════╪═══════════╪═════════════════════╡
# │ -3.629606 ┆ 8.985989 ┆ 5.137255 ┆ -7.497547 ┆ -8.366246 ┆ 2018-01-14 00:00:00 │
# └───────────┴──────────┴──────────┴───────────┴───────────┴─────────────────────┘

# %%
import pandas as pd

# Try reading the file using pandas.read_stata (since the extension is .dta, likely Stata format)
df_sf_rf = pd.read_stata("../data_manual/treasury_sf_implied_rf.dta")

# %%
for n in [2, 5, 10, 20, 30]:
    df_sf_rf[f"spread_{n}"] = df_sf_rf[f"tfut_{n}_rf"] - df_sf_rf[f"tfut_ois_{n}"]

# %%
df_sf_rf.tail(200)
# Out:
#            date   tfut_2_rf  tfut_2_ttm  tfut_ois_2   tfut_5_rf  tfut_5_ttm  \
# 4767 2023-05-15  460.951996       137.0  508.082001  492.795013       137.0
# 4768 2023-05-16  463.592010       136.0  509.051788  493.705994       136.0
# 4769 2023-05-17  455.622986       135.0  511.579987  498.585999       135.0
# 4770 2023-05-18  454.040009       134.0  516.007568  497.915985       134.0
# 4771 2023-05-19  450.122986       133.0  513.648865  498.872986       133.0
# ...         ...         ...         ...         ...         ...         ...
# 4962 2024-02-23  472.351990         NaN         NaN  516.903015         NaN
# 4963 2024-02-26  474.596985         NaN         NaN  519.463989         NaN
# 4964 2024-02-27  471.479004         NaN         NaN  518.603027         NaN
# 4965 2024-02-28  469.110992         NaN         NaN  514.466980         NaN
# 4966 2024-02-29         NaN         NaN         NaN         NaN         NaN
#
#       tfut_ois_5  tfut_10_rf  tfut_10_ttm  tfut_ois_10  ...  tfut_20_ttm  \
# 4767  508.082001  497.727997        137.0   508.082001  ...        137.0
# 4768  509.051788  498.733002        136.0   509.051788  ...        136.0
# 4769  511.579987  500.313995        135.0   511.579987  ...        135.0
# 4770  516.007568  498.179993        134.0   516.007568  ...        134.0
# 4771  513.648865  498.687012        133.0   513.648865  ...        133.0
# ...          ...         ...          ...          ...  ...          ...
# 4962         NaN  516.239990          NaN          NaN  ...          NaN
# 4963         NaN  518.020020          NaN          NaN  ...          NaN
# 4964         NaN  512.820007          NaN          NaN  ...          NaN
# 4965         NaN  518.062012          NaN          NaN  ...          NaN
# 4966         NaN         NaN          NaN          NaN  ...          NaN
#
#       tfut_ois_20  tfut_30_rf  tfut_30_ttm  tfut_ois_30   spread_2   spread_5  \
# 4767   508.082001  441.964996        137.0   508.082001 -47.130005 -15.286987
# 4768   509.051788  436.994995        136.0   509.051788 -45.459778 -15.345795
# 4769   511.579987  427.920990        135.0   511.579987 -55.957001 -12.993988
# 4770   516.007568  428.407013        134.0   516.007568 -61.967560 -18.091583
# 4771   513.648865  431.404999        133.0   513.648865 -63.525879 -14.775879
# ...           ...         ...          ...          ...        ...        ...
# 4962          NaN  340.785004          NaN          NaN        NaN        NaN
# 4963          NaN  348.949005          NaN          NaN        NaN        NaN
# 4964          NaN  337.423004          NaN          NaN        NaN        NaN
# 4965          NaN  339.269012          NaN          NaN        NaN        NaN
# 4966          NaN         NaN          NaN          NaN        NaN        NaN
#
#       spread_10  spread_20  spread_30
# 4767 -10.354004 -41.989014 -66.117004
# 4768 -10.318787 -49.124786 -72.056793
# 4769 -11.265991 -54.550995 -83.658997
# 4770 -17.827576 -53.699554 -87.600555
# 4771 -14.961853 -43.925873 -82.243866
# ...         ...        ...        ...
# 4962        NaN        NaN        NaN
# 4963        NaN        NaN        NaN
# 4964        NaN        NaN        NaN
# 4965        NaN        NaN        NaN
# 4966        NaN        NaN        NaN
#
# [200 rows x 21 columns]

# %%
min_tfut_2_ttm = df_sf_rf["tfut_2_ttm"].min()
print("Min value of tfut_2_ttm:", min_tfut_2_ttm)
# Out:
# Min value of tfut_2_ttm: 88.0

# %%
df_sf_rf_mean = df_sf_rf.mean()
df_sf_rf_median = df_sf_rf.median()
print("Column means:")
print(df_sf_rf_mean)
print("\nColumn medians:")
print(df_sf_rf_median)
# Out:
# Column means:
# date           2014-04-24 10:19:15.305012992
# tfut_2_rf                         128.984467
# tfut_2_ttm                        129.988375
# tfut_ois_2                        147.428162
# tfut_5_rf                         151.033096
# tfut_5_ttm                        133.935004
# tfut_ois_5                        158.228928
# tfut_10_rf                         136.42543
# tfut_10_ttm                       145.024504
# tfut_ois_10                       157.608276
# tfut_20_rf                        142.081207
# tfut_20_ttm                       145.254202
# tfut_ois_20                       156.306488
# tfut_30_rf                         96.594368
# tfut_30_ttm                       132.913859
# tfut_ois_30                       102.398773
# spread_2                          -27.326719
# spread_5                          -15.012644
# spread_10                         -29.487568
# spread_20                         -22.061771
# spread_30                         -15.735785
# dtype: object
#
# Column medians:
# date           2014-04-23 00:00:00
# tfut_2_rf                   51.702
# tfut_2_ttm                   129.0
# tfut_ois_2               41.232224
# tfut_5_rf                74.859001
# tfut_5_ttm                   134.0
# tfut_ois_5               51.743057
# tfut_10_rf               63.969002
# tfut_10_ttm                  145.0
# tfut_ois_10              48.096558
# tfut_20_rf               52.288498
# tfut_20_ttm                  146.0
# tfut_ois_20              46.410778
# tfut_30_rf               36.483501
# tfut_30_ttm                  132.0
# tfut_ois_30              23.087778
# spread_2                -10.917334
# spread_5                 -2.834999
# spread_10               -14.750889
# spread_20               -17.417408
# spread_30                 -0.80378
# dtype: object

# %%
# Load arbitrage implied rf (wide)
df_arb_implied_rf = pd.read_stata("../data_manual/arbitrage_implied_rf_wide.dta")
df_arb_implied_rf
# Out:
#            date  cip_aud_rf  cip_cad_rf  cip_chf_rf  cip_eur_rf  cip_gbp_rf  \
# 0    2001-12-04  227.645401         NaN  188.814026  184.684860  187.289230
# 1    2001-12-05  227.005219         NaN  193.012970  186.848602  196.825348
# 2    2001-12-06  228.461090         NaN  195.464264  190.215576  192.339951
# 3    2001-12-07  230.756714         NaN  187.464371  183.196411  193.966675
# 4    2001-12-10  224.364578         NaN  182.922729  179.334213  185.234436
# ...         ...         ...         ...         ...         ...         ...
# 5798 2024-02-23  541.233948  552.870850  547.398315  539.081909  542.819031
# 5799 2024-02-26  540.026184  553.250488  545.318359  537.841248  543.275513
# 5800 2024-02-27  541.000977  552.377930  553.536438  540.851135  542.917297
# 5801 2024-02-28  543.378418  553.159729  561.548157  543.060303  542.612000
# 5802 2024-02-29  541.148926  553.652466  552.253845  539.242126  541.616272
#
#       cip_jpy_rf  cip_nzd_rf  cip_sek_rf  box_6m_rf  ...  tfut_10_rf  \
# 0            NaN         NaN         NaN        NaN  ...         NaN
# 1            NaN         NaN         NaN        NaN  ...         NaN
# 2            NaN         NaN         NaN        NaN  ...         NaN
# 3            NaN         NaN         NaN        NaN  ...         NaN
# 4            NaN         NaN         NaN        NaN  ...         NaN
# ...          ...         ...         ...        ...  ...         ...
# 5798  562.275330  557.172974  546.160522        NaN  ...  516.239990
# 5799  557.886414  555.220581  543.445862        NaN  ...  518.020020
# 5800  569.142822  554.287109  547.271851        NaN  ...  512.820007
# 5801  581.052368  554.353577  549.954346        NaN  ...  518.062012
# 5802  567.945068  554.106873  545.923828        NaN  ...         NaN
#
#       tfut_20_rf  tfut_30_rf  tswap_1_rf  tswap_2_rf  tswap_3_rf  tswap_5_rf  \
# 0            NaN         NaN      214.60         NaN         NaN         NaN
# 1            NaN         NaN      235.10         NaN         NaN         NaN
# 2            NaN         NaN      239.80         NaN         NaN         NaN
# 3            NaN         NaN      231.30         NaN         NaN         NaN
# 4            NaN         NaN      219.20         NaN         NaN         NaN
# ...          ...         ...         ...         ...         ...         ...
# 5798  472.078003  340.785004      506.46      453.70      424.52      398.22
# 5799  466.795013  348.949005      508.58      456.50      427.12      400.35
# 5800  467.937012  337.423004      508.60      457.05      427.80      401.68
# 5801  451.751007  339.269012      504.94      451.77      422.95      397.10
# 5802         NaN         NaN      503.26      449.95      421.46      396.40
#
#       tswap_10_rf  tswap_20_rf  tswap_30_rf
# 0             NaN          NaN          NaN
# 1             NaN          NaN          NaN
# 2             NaN          NaN          NaN
# 3             NaN          NaN          NaN
# 4             NaN          NaN          NaN
# ...           ...          ...          ...
# 5798       383.69       379.56       359.97
# 5799       385.90       381.30       362.02
# 5800       387.96       384.16       364.83
# 5801       384.46       381.35       362.45
# 5802       383.50       379.36       359.95
#
# [5803 rows x 33 columns]

# %%
# Load arbitrage spread (wide)
df_arb_spread = pd.read_stata("../data_manual/arbitrage_spread_wide.dta")
df_arb_spread
# Out:
#            date  box_12m  box_18m  box_6m  cal_dow  cal_ndaq  cal_spx  \
# 0    2001-12-04      NaN      NaN     NaN      NaN       NaN      NaN
# 1    2001-12-05      NaN      NaN     NaN      NaN       NaN      NaN
# 2    2001-12-06      NaN      NaN     NaN      NaN       NaN      NaN
# 3    2001-12-07      NaN      NaN     NaN      NaN       NaN      NaN
# 4    2001-12-10      NaN      NaN     NaN      NaN       NaN      NaN
# ...         ...      ...      ...     ...      ...       ...      ...
# 5558 2024-02-22      NaN      NaN     NaN      NaN       NaN      NaN
# 5559 2024-02-23      NaN      NaN     NaN      NaN       NaN      NaN
# 5560 2024-02-26      NaN      NaN     NaN      NaN       NaN      NaN
# 5561 2024-02-27      NaN      NaN     NaN      NaN       NaN      NaN
# 5562 2024-02-28      NaN      NaN     NaN      NaN       NaN      NaN
#
#       cds_bond_hy  cds_bond_ig    cip_aud  ...  raw_tips_treas_2  \
# 0             NaN          NaN  52.145401  ...               NaN
# 1             NaN          NaN  46.005219  ...               NaN
# 2             NaN          NaN  49.061096  ...               NaN
# 3             NaN          NaN  58.456711  ...               NaN
# 4             NaN          NaN  53.464584  ...               NaN
# ...           ...          ...        ...  ...               ...
# 5558          NaN          NaN   8.251404  ...               NaN
# 5559          NaN          NaN   6.583923  ...               NaN
# 5560          NaN          NaN   5.156189  ...               NaN
# 5561          NaN          NaN   6.320984  ...               NaN
# 5562          NaN          NaN   8.978394  ...               NaN
#
#       raw_tips_treas_20  raw_tips_treas_5  raw_tswap_1  raw_tswap_10  \
# 0                   NaN               NaN         7.60           NaN
# 1                   NaN               NaN         8.10           NaN
# 2                   NaN               NaN         4.80           NaN
# 3                   NaN               NaN         5.30           NaN
# 4                   NaN               NaN         2.20           NaN
# ...                 ...               ...          ...           ...
# 5558                NaN               NaN         4.56    -41.220001
# 5559                NaN               NaN         6.46    -42.310001
# 5560                NaN               NaN         5.58    -42.099998
# 5561                NaN               NaN         5.60    -43.040001
# 5562                NaN               NaN         4.94    -42.540001
#
#       raw_tswap_2  raw_tswap_20  raw_tswap_3  raw_tswap_30  raw_tswap_5
# 0             NaN           NaN          NaN           NaN          NaN
# 1             NaN           NaN          NaN           NaN          NaN
# 2             NaN           NaN          NaN           NaN          NaN
# 3             NaN           NaN          NaN           NaN          NaN
# 4             NaN           NaN          NaN           NaN          NaN
# ...           ...           ...          ...           ...          ...
# 5558       -13.77    -69.800003   -21.139999    -78.449997   -29.330000
# 5559       -13.30    -71.440002   -20.480000    -77.029999   -29.780001
# 5560       -12.50    -71.699997   -20.879999    -77.980003   -28.650000
# 5561       -12.95    -72.839996   -22.200001    -79.169998   -30.320000
# 5562       -12.23    -71.650002   -21.049999    -77.550003   -28.900000
#
# [5563 rows x 65 columns]

# %%
df_arb_spread.columns
# Out:
# Index(['date', 'box_12m', 'box_18m', 'box_6m', 'cal_dow', 'cal_ndaq',
#        'cal_spx', 'cds_bond_hy', 'cds_bond_ig', 'cip_aud', 'cip_cad',
#        'cip_chf', 'cip_eur', 'cip_gbp', 'cip_jpy', 'cip_nzd', 'cip_sek',
#        'tfut_10', 'tfut_2', 'tfut_20', 'tfut_30', 'tfut_5', 'tips_treas_10',
#        'tips_treas_2', 'tips_treas_20', 'tips_treas_5', 'tswap_1', 'tswap_10',
#        'tswap_2', 'tswap_20', 'tswap_3', 'tswap_30', 'tswap_5', 'raw_box_12m',
#        'raw_box_18m', 'raw_box_6m', 'raw_cal_dow', 'raw_cal_ndaq',
#        'raw_cal_spx', 'raw_cds_bond_hy', 'raw_cds_bond_ig', 'raw_cip_aud',
#        'raw_cip_cad', 'raw_cip_chf', 'raw_cip_eur', 'raw_cip_gbp',
#        'raw_cip_jpy', 'raw_cip_nzd', 'raw_cip_sek', 'raw_tfut_10',
#        'raw_tfut_2', 'raw_tfut_20', 'raw_tfut_30', 'raw_tfut_5',
#        'raw_tips_treas_10', 'raw_tips_treas_2', 'raw_tips_treas_20',
#        'raw_tips_treas_5', 'raw_tswap_1', 'raw_tswap_10', 'raw_tswap_2',
#        'raw_tswap_20', 'raw_tswap_3', 'raw_tswap_30', 'raw_tswap_5'],
#       dtype='object')

# %%
selected_cols = [
    'date', 'tswap_1', 'tswap_10', 'tswap_2', 'tswap_20', 'tswap_3', 'tswap_30', 'tswap_5',
    'tfut_10', 'tfut_2', 'tfut_20', 'tfut_30', 'tfut_5',
]
display(df_arb_spread[selected_cols])
target = df_arb_spread['tfut_2']
# Out:
#            date  tswap_1   tswap_10  tswap_2   tswap_20    tswap_3   tswap_30  \
# 0    2001-12-04     7.60        NaN      NaN        NaN        NaN        NaN
# 1    2001-12-05     8.10        NaN      NaN        NaN        NaN        NaN
# 2    2001-12-06     4.80        NaN      NaN        NaN        NaN        NaN
# 3    2001-12-07     5.30        NaN      NaN        NaN        NaN        NaN
# 4    2001-12-10     2.20        NaN      NaN        NaN        NaN        NaN
# ...         ...      ...        ...      ...        ...        ...        ...
# 5558 2024-02-22     4.56  41.220001    13.77  69.800003  21.139999  78.449997
# 5559 2024-02-23     6.46  42.310001    13.30  71.440002  20.480000  77.029999
# 5560 2024-02-26     5.58  42.099998    12.50  71.699997  20.879999  77.980003
# 5561 2024-02-27     5.60  43.040001    12.95  72.839996  22.200001  79.169998
# 5562 2024-02-28     4.94  42.540001    12.23  71.650002  21.049999  77.550003
#
#         tswap_5    tfut_10     tfut_2    tfut_20     tfut_30     tfut_5
# 0           NaN        NaN        NaN        NaN         NaN        NaN
# 1           NaN        NaN        NaN        NaN         NaN        NaN
# 2           NaN        NaN        NaN        NaN         NaN        NaN
# 3           NaN        NaN        NaN        NaN         NaN        NaN
# 4           NaN        NaN        NaN        NaN         NaN        NaN
# ...         ...        ...        ...        ...         ...        ...
# 5558  29.330000  16.325012  59.458984  74.609985  211.763977  16.096008
# 5559  29.780001  15.239990  59.127991  59.401978  190.694977  14.576965
# 5560  28.650000  14.094971  57.518005  65.319977  183.165985  12.651001
# 5561  30.320000  18.984985  60.325989  63.867981  194.381989  13.201965
# 5562  28.900000  12.888000  61.839020  79.199005  191.681000  16.483032
#
# [5563 rows x 13 columns]

# %%
# Load arbitrage strategy (wide)
df_arb_strategy = pd.read_stata("../data_manual/arbitrage_strategy_wide.dta")
df_arb_strategy
# Out:
#            date        cip  cal_spread  box_spread  tips_treas      tswap  \
# 0    2001-12-04  21.608379         NaN         NaN         NaN   7.600000
# 1    2001-12-05  19.923035         NaN         NaN         NaN   8.100000
# 2    2001-12-06  22.220226         NaN         NaN         NaN   4.800000
# 3    2001-12-07  26.546040         NaN         NaN         NaN   5.300000
# 4    2001-12-10  22.063995         NaN         NaN         NaN   2.200000
# ...         ...        ...         ...         ...         ...        ...
# 5558 2024-02-22  14.494972         NaN         NaN         NaN  36.895714
# 5559 2024-02-23  13.976585         NaN         NaN         NaN  37.257145
# 5560 2024-02-26  12.163086         NaN         NaN         NaN  37.055714
# 5561 2024-02-27  15.493202         NaN         NaN         NaN  38.017143
# 5562 2024-02-28  19.239838         NaN         NaN         NaN  36.980000
#
#            tfut  cds_bond  cip_k  cal_spread_k  box_spread_k  tswap_k  tfut_k  \
# 0           NaN       NaN    8.0           3.0           3.0      7.0     5.0
# 1           NaN       NaN    8.0           3.0           3.0      7.0     5.0
# 2           NaN       NaN    8.0           3.0           3.0      7.0     5.0
# 3           NaN       NaN    8.0           3.0           3.0      7.0     5.0
# 4           NaN       NaN    8.0           3.0           3.0      7.0     5.0
# ...         ...       ...    ...           ...           ...      ...     ...
# 5558  75.650795       NaN    8.0           3.0           3.0      7.0     5.0
# 5559  67.808380       NaN    8.0           3.0           3.0      7.0     5.0
# 5560  66.549988       NaN    8.0           3.0           3.0      7.0     5.0
# 5561  70.152580       NaN    8.0           3.0           3.0      7.0     5.0
# 5562  72.418015       NaN    8.0           3.0           3.0      7.0     5.0
#
#       cds_bond_k  tips_treas_k
# 0            2.0           4.0
# 1            2.0           4.0
# 2            2.0           4.0
# 3            2.0           4.0
# 4            2.0           4.0
# ...          ...           ...
# 5558         2.0           4.0
# 5559         2.0           4.0
# 5560         2.0           4.0
# 5561         2.0           4.0
# 5562         2.0           4.0
#
# [5563 rows x 15 columns]

# %% [markdown]
# ## I Do NOT Know If Target is Our Actual Target

# %%
import matplotlib.pyplot as plt

# Define the date range
start_date = '2010-01-01'
end_date = '2024-02-28'

# Ensure 'date' is in datetime format
df_arb_spread['date'] = pd.to_datetime(df_arb_spread['date'])

# Filter for selected date range
mask = (df_arb_spread['date'] >= start_date) & (df_arb_spread['date'] <= end_date)
df_filtered = df_arb_spread.loc[mask].copy()
date_range = df_filtered['date']

# Properly align "mine" and "target" to the filtered DataFrame by date
# Assume mine/target are Series or arrays covering the same full period as df_arb_spread
# If they are not indexed by date, extract the appropriate values from original DataFrame within date_range
# The code will try to handle both "indexed by date" or just arrays

def extract_aligned(series_like, filtered_df, colname=None):
    import pandas as pd
    import numpy as np
    # If it's a Series with matching index or column name, align on date
    if isinstance(series_like, pd.Series):
        # If the index is date or same shape, try to align by index
        try:
            aligned = series_like.loc[filtered_df.index]
            return aligned.values
        except Exception:
            pass
    # If given as a DataFrame and colname is specified
    if isinstance(series_like, pd.DataFrame) and colname:
        try:
            return series_like.loc[filtered_df.index, colname].values
        except Exception:
            pass
    # If mine/target are simply arrays, slice according to length (WARNING: this assumes same start alignment!)
    arr = getattr(series_like, "values", None)
    if arr is None:
        arr = getattr(series_like, "to_numpy", lambda: np.asarray(series_like))()
    # If filtering by date reduced DataFrame, match up by slicing or pad if needed
    if len(arr) >= len(filtered_df):
        return arr[:len(filtered_df)]
    else:
        return np.pad(arr, (0, len(filtered_df) - len(arr)), constant_values=np.nan)

# If mine/target are actually columns in df_arb_spread, pull from filtered version
mine_in_df = 'mine' in df_filtered.columns
target_in_df = 'target' in df_filtered.columns
if mine_in_df:
    mine_aligned = df_filtered['mine'].values
else:
    mine_aligned = extract_aligned(mine, df_filtered)
if target_in_df:
    target_aligned = df_filtered['target'].values
elif isinstance(target, pd.Series) and (target.index.equals(df_arb_spread.index) or target.index.equals(df_arb_spread['date'])):
    # Likely same length, just slice using the mask
    target_aligned = target[mask].values
else:
    # Try just aligning by position
    target_aligned = extract_aligned(target, df_filtered)

# Make sure all columns have the same length
min_len = min(len(date_range), len(mine_aligned), len(target_aligned))

plot_df = pd.DataFrame({
    "date": date_range.iloc[:min_len].values,
    "mine": mine_aligned[:min_len],
    "target": target_aligned[:min_len]
})

# Drop NA rows for plotting purposes (optional: drop where both mine and target are nan)
plot_df = plot_df.dropna(subset=["mine", "target"], how="all")

# -- Debug: Check for completely empty or all-NA target data
if plot_df['target'].isna().all():
    print("WARNING: All values in 'target' are NaN after alignment and filtering. Check target length/index or how you extract target values.")
    print(f"target_aligned shape: {target_aligned.shape}")
    # Optionally print some sample of target_aligned for debugging
    print("First 10 of target_aligned:", target_aligned[:10])

plt.figure(figsize=(12, 6))
plt.plot(plot_df['date'], plot_df['mine'], label='mine')
plt.plot(plot_df['date'], plot_df['target'], label='target')
plt.xlabel('Date')
plt.ylabel('Value')
plt.title('Mine & Target over Time (2010-01-01 to 2024-02-28)')
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_squared_error
import numpy as np

# Compute RMSE between 'mine' and 'target' over 2010-01-01 to 2024-02-28
mine_vals = plot_df['mine'].values
target_vals = plot_df['target'].values

# Drop pairs where either value is nan
mask = ~((np.isnan(mine_vals)) | (np.isnan(target_vals)))
if mask.sum() == 0:
    print("No valid data to compute RMSE (all values are NaN or masked).")
else:
    rmse = np.sqrt(mean_squared_error(mine_vals[mask], target_vals[mask]))
    print(f"RMSE between 'mine' and 'target' (2010-01-01 to 2024-02-28): {rmse:.4f}")
# Out:
# RMSE between 'mine' and 'target' (2010-01-01 to 2024-02-28): 47.7629

# %%
# Calculate correlation between 'mine' and 'target' in plot_df
# Drop pairs where either is nan
mine_vals = plot_df['mine'].values
target_vals = plot_df['target'].values
mask = ~((np.isnan(mine_vals)) | (np.isnan(target_vals)))

if mask.sum() == 0:
    print("No valid data to compute correlation (all values are NaN or masked).")
else:
    corr = np.corrcoef(mine_vals[mask], target_vals[mask])[0, 1]
    print(f"Correlation between 'mine' and 'target' (2010-01-01 to 2024-02-28): {corr:.4f}")
# Out:
# Correlation between 'mine' and 'target' (2010-01-01 to 2024-02-28): -0.2696

# %%
# Compare my IRR to Bloomberg's IRR for all contracts (2010–2020)
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error

# Date range (up to 2020)
start_date = pl.date(2010, 1, 1)
end_date = pl.date(2020, 1, 1)

# Tenor -> Bloomberg ticker prefix (for finding fut_implied_repo_rt column)
TENOR_BBG = {"2Y": "TU2", "5Y": "FV2", "10Y": "TY2", "20Y": "WN2", "30Y": "US2"}
tenors = list(TENOR_BBG.keys())

# My IRR: filter once, cast Date, only up to 2020
my_irr_all = (
    df_irr.filter(pl.col("Date").is_between(start_date, end_date, closed="left"))
    .with_columns(pl.col("Date").cast(pl.Date))
)

# Bloomberg: filter once by date, only up to 2020
df_bbg = df.filter(pl.col("Date").is_between(start_date, end_date, closed="left"))

fig, axes = plt.subplots(5, 1, figsize=(10, 12), sharex=True)
results = []

for i, tenor in enumerate(tenors):
    bbg_prefix = TENOR_BBG[tenor]
    bbg_col = [c for c in df.columns if bbg_prefix in str(c) and "fut_implied_repo_rt" in str(c)]
    if not bbg_col:
        axes[i].set_title(f"{tenor}: no Bloomberg column")
        continue
    bbg_col = bbg_col[0]

    my_irr = my_irr_all.select(["Date", pl.col(tenor).alias("my_irr_bps")])
    bbg_irr = df_bbg.select([
        "Date",
        (pl.col(bbg_col) * 100).alias("bloomberg_irr_bps"),  # percent -> bps
    ])
    compare = my_irr.join(bbg_irr, on="Date", how="inner")
    compare_clean = compare.filter(
        pl.col("my_irr_bps").is_not_nan() & pl.col("bloomberg_irr_bps").is_not_nan()
    )

    ax = axes[i]
    ax.plot(compare_clean["Date"], compare_clean["my_irr_bps"], label=f"My IRR ({tenor})", alpha=0.8)
    ax.plot(compare_clean["Date"], compare_clean["bloomberg_irr_bps"], label=f"Bloomberg ({tenor})", alpha=0.8)
    ax.set_ylabel("bps")
    ax.set_title(f"{tenor}")
    ax.legend(loc="upper right", fontsize=8)
    ax.grid(True, alpha=0.3)

    my_vals = compare_clean["my_irr_bps"].to_numpy()
    bbg_vals = compare_clean["bloomberg_irr_bps"].to_numpy()
    n = len(my_vals)
    if n > 0:
        rmse = (mean_squared_error(my_vals, bbg_vals)) ** 0.5
        corr = np.corrcoef(my_vals, bbg_vals)[0, 1]
        results.append({"tenor": tenor, "n": n, "rmse_bps": rmse, "corr": corr})
    else:
        results.append({"tenor": tenor, "n": 0, "rmse_bps": np.nan, "corr": np.nan})

axes[-1].set_xlabel("Date")
fig.suptitle("My IRR vs Bloomberg IRR (2010–2020)", y=1.02)
plt.tight_layout()
plt.show()

# Summary table
print("2010–2020 comparison by contract:")
print(pl.DataFrame(results))
# Out:
# 2010–2020 comparison by contract:
# shape: (5, 4)
# ┌───────┬──────┬───────────┬──────────┐
# │ tenor ┆ n    ┆ rmse_bps  ┆ corr     │
# │ ---   ┆ ---  ┆ ---       ┆ ---      │
# │ str   ┆ i64  ┆ f64       ┆ f64      │
# ╞═══════╪══════╪═══════════╪══════════╡
# │ 2Y    ┆ 2307 ┆ 9.976158  ┆ 0.996055 │
# │ 5Y    ┆ 2349 ┆ 15.410952 ┆ 0.985347 │
# │ 10Y   ┆ 2435 ┆ 66.77361  ┆ 0.874929 │
# │ 20Y   ┆ 1700 ┆ 59.703915 ┆ 0.810697 │
# │ 30Y   ┆ 2453 ┆ 38.053397 ┆ 0.909409 │
# └───────┴──────┴───────────┴──────────┘

# %%
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler
import pandas as pd

print("RMSE of normalized (z-scored) my_irr_bps vs bloomberg_irr_bps for each tenor (pre-2020 only):")
for i, tenor in enumerate(tenors):
    bbg_prefix = TENOR_BBG[tenor]
    bbg_col = [c for c in df.columns if bbg_prefix in str(c) and "fut_implied_repo_rt" in str(c)]
    if not bbg_col:
        print(f"{tenor}: no Bloomberg column")
        continue
    bbg_col = bbg_col[0]

    my_irr = my_irr_all.select(["Date", pl.col(tenor).alias("my_irr_bps")])
    bbg_irr = df_bbg.select([
        "Date",
        (pl.col(bbg_col) * 100).alias("bloomberg_irr_bps"),  # percent -> bps
    ])
    compare = my_irr.join(bbg_irr, on="Date", how="inner")
    compare_clean = compare.filter(
        pl.col("my_irr_bps").is_not_nan() & pl.col("bloomberg_irr_bps").is_not_nan()
    )

    # Filter for only pre-2020 dates
    compare_clean = compare_clean.filter(pl.col("Date") < pd.Timestamp("2020-01-01"))

    compare_clean_pd = compare_clean.to_pandas()

    if compare_clean_pd.shape[0] == 0:
        print(f"{tenor}: no data")
        continue

    # Normalize the two IRR columns separately (z-score normalization)
    scaler = StandardScaler()
    normalized = scaler.fit_transform(compare_clean_pd[["my_irr_bps", "bloomberg_irr_bps"]])

    my_irr_norm = normalized[:, 0]
    bbg_irr_norm = normalized[:, 1]

    # Compute RMSE of the normalized values
    rmse_norm = (mean_squared_error(my_irr_norm, bbg_irr_norm)) ** 0.5

    print(f"{tenor}: RMSE = {rmse_norm:.4f}")
# Out:
# RMSE of normalized (z-scored) my_irr_bps vs bloomberg_irr_bps for each tenor (pre-2020 only):
# 2Y: RMSE = 0.0888
# 5Y: RMSE = 0.1712
# 10Y: RMSE = 0.2566
# 20Y: RMSE = 0.6153
# 30Y: RMSE = 0.4257
