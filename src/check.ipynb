# %%
import polars as pl

# %%
df = pl.read_parquet("bloomberg.parquet")

# %%
df
# Out:
# shape: (521, 60)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ ('TY1     ┆ ('TY1     ┆ ('TY1     ┆ ('TY1     ┆ … ┆ ('USSO2   ┆ ('USSO3   ┆ ('USSO4   ┆ Date     │
# │ Comdty',  ┆ Comdty',  ┆ Comdty',  ┆ Comdty',  ┆   ┆ CMPN      ┆ CMPN      ┆ CMPN      ┆ ---      │
# │ 'fut_impl ┆ 'px_volum ┆ 'current_ ┆ 'px_last' ┆   ┆ Curncy',  ┆ Curncy',  ┆ Curncy',  ┆ date     │
# │ ied_re…   ┆ e')       ┆ contra…   ┆ )         ┆   ┆ 'px_last… ┆ 'px_last… ┆ 'px_last… ┆          │
# │ ---       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆          │
# │ f64       ┆ f64       ┆ str       ┆ f64       ┆   ┆ f64       ┆ f64       ┆ f64       ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ -0.45551  ┆ 611675.0  ┆ MAR 10    ┆ 115.53125 ┆ … ┆ 1.141     ┆ 1.781     ┆ 2.2965    ┆ 2010-01- │
# ...

# %%
df.null_count()
# Out:
# shape: (1, 60)
# ┌────────────┬────────────┬────────────┬────────────┬───┬───────────┬───────────┬───────────┬──────┐
# │ ('TY1      ┆ ('TY1      ┆ ('TY1      ┆ ('TY1      ┆ … ┆ ('USSO2   ┆ ('USSO3   ┆ ('USSO4   ┆ Date │
# │ Comdty',   ┆ Comdty',   ┆ Comdty',   ┆ Comdty',   ┆   ┆ CMPN      ┆ CMPN      ┆ CMPN      ┆ ---  │
# │ 'fut_impli ┆ 'px_volume ┆ 'current_c ┆ 'px_last') ┆   ┆ Curncy',  ┆ Curncy',  ┆ Curncy',  ┆ u32  │
# │ ed_re…     ┆ ')         ┆ ontra…     ┆ ---        ┆   ┆ 'px_last… ┆ 'px_last… ┆ 'px_last… ┆      │
# │ ---        ┆ ---        ┆ ---        ┆ u32        ┆   ┆ ---       ┆ ---       ┆ ---       ┆      │
# │ u32        ┆ u32        ┆ u32        ┆            ┆   ┆ u32       ┆ u32       ┆ u32       ┆      │
# ╞════════════╪════════════╪════════════╪════════════╪═══╪═══════════╪═══════════╪═══════════╪══════╡
# │ 20         ┆ 15         ┆ 17         ┆ 16         ┆ … ┆ 0         ┆ 0         ┆ 0         ┆ 0    │
# ...

# %%
df.__len__()
# Out:
# 521
